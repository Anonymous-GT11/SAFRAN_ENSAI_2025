# %% [markdown]
# <a href="https://colab.research.google.com/github/sthepaut/SAFRAN_ENSAI_2025/blob/ENSAI_students/%20%20%20%20performancemodel_ENSAI/notebook/GA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Anonymous-GT11/SAFRAN_ENSAI_2025
# !git clone -b ENSAI_students https://github.com/Anonymous-GT11/SAFRAN_ENSAI_2025
# Out:
# Cloning into 'SAFRAN_ENSAI_2025'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 297 (delta 39), reused 32 (delta 32), pack-reused 249 (from 1)
# Receiving objects: 100% (297/297), 12.55 MiB | 11.74 MiB/s, done.
# Resolving deltas: 100% (163/163), done.
